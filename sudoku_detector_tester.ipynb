# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas1209/Sudoku_Solver_App/blob/main/sudoku_detector_tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sudoku_detector(img):
#
# Transforms on image:
#
# 1.cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) converts the image to grayscale
#
# 2.Adding GaussianBlur
#
#
# 3.Image thresholding is an important intermediary step for image processing pipelines. Thresholding can help us to remove lighter or darker regions and contours of images

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
image = cv2.imread('/content/gdrive/MyDrive/Sudoku/sample_sudoku.jpg')
image1 = cv2.imread('/content/gdrive/MyDrive/Sudoku/sample_sudoku_1.jpg')
image2 = cv2.imread('/content/gdrive/MyDrive/Sudoku/sample_sudoku_3.jpg')

# %%
import sys

sys.path.append('/content/gdrive/MyDrive/Sudoku/Models')
sys.path.append('/content/gdrive/MyDrive/Sudoku')

# %%
from sudoku_detector import *

# %%
pic = sudoku_detector(image, show = True,dilate = False)
# Out:
# <PIL.Image.Image image mode=L size=768x817 at 0x7F524ADFA7D0>
# <PIL.Image.Image image mode=L size=768x817 at 0x7F5234D71D10>
# <PIL.Image.Image image mode=L size=768x817 at 0x7F5234D71A90>
# <PIL.Image.Image image mode=L size=768x817 at 0x7F5234D71DD0>

# %%
pic1 = sudoku_detector(image1, show = True)
# Out:
# <PIL.Image.Image image mode=L size=1600x1600 at 0x7F5234D7CF90>
# <PIL.Image.Image image mode=L size=1600x1600 at 0x7F5234D7CDD0>
# <PIL.Image.Image image mode=L size=1600x1600 at 0x7F5234D7CE90>
# <PIL.Image.Image image mode=L size=1600x1600 at 0x7F52357611D0>

# %%
pic2 = sudoku_detector(image2, show = True,dilate = False)
# Out:
# <PIL.Image.Image image mode=L size=240x320 at 0x7F5234D0AE10>
# <PIL.Image.Image image mode=L size=240x320 at 0x7F5234D0AC50>
# <PIL.Image.Image image mode=L size=240x320 at 0x7F5234D0A910>
# <PIL.Image.Image image mode=L size=240x320 at 0x7F5234D0A810>

# %%
boundary = find_boundary(image,pic)
# Out:
# <PIL.Image.Image image mode=RGB size=768x817 at 0x7F5234D0A4D0>
# <PIL.Image.Image image mode=L size=768x817 at 0x7F5234D0A710>

# %%
boundary1 = find_boundary(image1,pic1)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1600 at 0x7F5234D71A90>
# <PIL.Image.Image image mode=L size=1600x1600 at 0x7F5234D0A7D0>

# %%
boundary2 = find_boundary(image2,pic2)
# Out:
# <PIL.Image.Image image mode=RGB size=240x320 at 0x7F524ADFA710>
# <PIL.Image.Image image mode=L size=240x320 at 0x7F5235758A50>

# %%
crop = crop_and_warp(pic1,boundary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1808c7a5ed3f> in <module>()
# ----> 1 crop = crop_and_warp(pic1,boundary)
#
# /content/gdrive/MyDrive/Sudoku/sudoku_detector.py in crop_and_warp(img, box_array)
#     127   destination_pts = np.array([[0,0],[max_breadth-1,0],[max_breadth-1,max_length-1],[0,max_length-1]],dtype = "float32")
#     128   # compute the perspective transform matrix and then apply it
# --> 129   image_perspective = cv2.getPerspectiveTransform(box_array,destination_pts)
#     130   image_warped = cv2.warpPerspective(img,image_perspective,(max_breadth,max_length))
#     131   cv2_imshow(image_warped)
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'
